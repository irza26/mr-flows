# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine(
    "postgresql+psycopg2://postgres:postgres@localhost:5432/curahHujan_db"
)

# %%
df_ch = pd.read_sql("""
SELECT station, date + time AS timestamp, rainfall
FROM rainfall
ORDER BY station, timestamp
""", engine)

# %%
df_tma = pd.read_sql("""
SELECT station, date + time AS timestamp, water_level
FROM tma
ORDER BY station, timestamp
""", engine)

# %%
df_ch_per_station = {
    st: df.reset_index(drop=True)
    for st, df in df_ch.groupby("station")
}

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\impal-fin\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\impal-fin\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\impal-fin\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\impal-fin\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\impal-fin\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\impal-fin\.venv\lib\site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\impal-fin\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\impal-fin\.venv\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\impal-fin\.venv\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\impal-fin\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\impal-fin\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
start_date = "2025-02-01"

df_ch_per_station.pop("Nagrak", None)
for st in df_ch_per_station:
    df = df_ch_per_station[st].copy()
    df["timestamp"] = pd.to_datetime(df["timestamp"])
    df = df[df["timestamp"] >= start_date] 
    df_ch_per_station[st] = df

# %%
df_tma["timestamp"] = pd.to_datetime(df_tma["timestamp"])
df_tma = df_tma[df_tma["timestamp"] >= start_date]

# %%
print("CH range:")
for st in df_ch_per_station:
    print(st, 
          df_ch_per_station[st]["timestamp"].min(), 
          "→", 
          df_ch_per_station[st]["timestamp"].max())
print("\nTMA range:")
print(df_tma["timestamp"].min(), "→", df_tma["timestamp"].max())
# Out:
# CH range:
# Cihawuk 2025-02-01 00:00:00 → 2026-02-12 14:20:00
# Cikitu 2025-02-01 07:50:00 → 2026-02-12 14:20:00
# Ibun 2025-02-01 08:30:00 → 2026-02-12 14:20:00
# Kertasari 2025-02-01 00:00:00 → 2026-02-12 14:20:00
# Paseh Cipaku 2025-02-01 00:00:00 → 2026-02-12 14:20:00
#
# TMA range:
# 2025-02-01 00:00:00 → 2026-02-12 14:10:00

# %%
import numpy as np

df_tma.loc[df_tma["water_level"] <= 0, "water_level"] = np.nan
df_tma.loc[df_tma["water_level"] > 4.5, "water_level"] = np.nan

# %%
THRESHOLD_GLOBAL = 50

for st in df_ch_per_station:
    df = df_ch_per_station[st]    
    df.loc[df["rainfall"] > THRESHOLD_GLOBAL, "rainfall"] = np.nan    
    df_ch_per_station[st] = df

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(6, 1, figsize=(14,16), sharex=True)

for i, (st, df) in enumerate(df_ch_per_station.items()):
    
    axes[i].plot(
        df["timestamp"],
        df["rainfall"],
        linewidth=0.6
    )
    
    axes[i].set_title(f"CH - {st}")
    axes[i].grid(True)

axes[5].plot(
    df_tma["timestamp"],
    df_tma["water_level"],
    color="red",
    linewidth=0.8
)

axes[5].set_title("TMA - Bendung Wanir")
axes[5].grid(True)

plt.tight_layout()
plt.show()

# %%
for st in df_ch_per_station:
    df_ch_per_station[st] = df_ch_per_station[st].copy()
    df_ch_per_station[st]["timestamp"] = pd.to_datetime(
        df_ch_per_station[st]["timestamp"]
    )
    df_ch_per_station[st] = df_ch_per_station[st].set_index("timestamp")

# %%
ch_all = pd.concat(
    {st: df["rainfall"] for st, df in df_ch_per_station.items()},
    axis=1
)

# %%
ch_all["ch_mean"] = ch_all.sum(axis=1)

# %%
df_tma = df_tma.copy()
df_tma["timestamp"] = pd.to_datetime(df_tma["timestamp"])
df_tma = df_tma.set_index("timestamp")
df_model = pd.concat(
    [df_tma["water_level"], ch_all["ch_mean"]],
    axis=1
)
df_model.columns = ["tma", "ch_mean"]

# %%
results = []

for lag in range(0, 36):
    
    corr = df_model["tma"].corr(
        df_model["ch_mean"].shift(lag)
    )
    
    results.append((lag, corr))
results_df = pd.DataFrame(results, columns=["lag", "correlation"])

# %%
best = results_df.loc[results_df["correlation"].idxmax()]
best
# Out:
# lag            18.000000
# correlation     0.379462
# Name: 18, dtype: float64

# %%
import numpy as np

max_lag = 36
results_station = {}

for st in ch_all.columns.drop("ch_mean", errors="ignore"):
    corrs = []
    for lag in range(max_lag):
        corr = df_tma["water_level"].corr(
            ch_all[st].shift(lag)
        )
        corrs.append(corr)
    corrs = np.array(corrs)
    best_lag = corrs.argmax()
    best_corr = corrs.max()
    results_station[st] = (best_lag, best_corr)

# %%
for st, (lag, corr) in results_station.items():
    print(f"{st}: lag={lag} ({lag*10} menit), corr={corr:.3f}")
# Out:
# Cihawuk: lag=21 (210 menit), corr=0.234
# Cikitu: lag=16 (160 menit), corr=0.274
# Ibun: lag=13 (130 menit), corr=0.340
# Kertasari: lag=18 (180 menit), corr=0.235
# Paseh Cipaku: lag=12 (120 menit), corr=0.194

# %%
best_lags = {
    "Cihawuk": 21,
    "Cikitu": 16,
    "Ibun": 13,
    "Kertasari": 18,
    "Paseh Cipaku": 12
}

# %%
ch_lagged = pd.DataFrame(index=ch_all.index)

for st, lag in best_lags.items():
    ch_lagged[st] = ch_all[st].shift(lag)

# %%
import itertools

results_combo = []

stations = list(best_lags.keys())

for r in range(1, len(stations)+1):
    for combo in itertools.combinations(stations, r):        
        ch_combo = ch_lagged[list(combo)].sum(axis=1)        
        corr = df_tma["water_level"].corr(ch_combo)
        results_combo.append((combo, r, corr))

# %%
results_df = pd.DataFrame(
    results_combo,
    columns=["stations", "n_station", "correlation"]
)

results_df = results_df.sort_values("correlation", ascending=False)

results_df.head(10)
# Out:
#                                             stations  n_station  correlation
# 30  (Cihawuk, Cikitu, Ibun, Kertasari, Paseh Cipaku)          5     0.415039
# 26             (Cihawuk, Cikitu, Ibun, Paseh Cipaku)          4     0.395343
# 25                (Cihawuk, Cikitu, Ibun, Kertasari)          4     0.394960
# 29           (Cikitu, Ibun, Kertasari, Paseh Cipaku)          4     0.387725
# 27        (Cihawuk, Cikitu, Kertasari, Paseh Cipaku)          4     0.378827
# 28          (Cihawuk, Ibun, Kertasari, Paseh Cipaku)          4     0.378305
# 15                           (Cihawuk, Cikitu, Ibun)          3     0.373142
# 21                         (Cikitu, Ibun, Kertasari)          3     0.366923
# 17                   (Cihawuk, Cikitu, Paseh Cipaku)          3     0.354417
# 18                        (Cihawuk, Ibun, Kertasari)          3     0.352296

# %%
ch_lagged_roll = ch_lagged.rolling(12).sum()
tma_diff = df_tma["water_level"].diff()
tma_diff_roll = tma_diff.rolling(12).sum()

# %%
import itertools

results_delta = []

stations = list(ch_lagged_roll.columns)

for r in range(1, len(stations)+1):
    
    for combo in itertools.combinations(stations, r):
        
        ch_combo = ch_lagged_roll[list(combo)].mean(axis=1)
        
        corr = tma_diff_roll.corr(ch_combo)
        
        results_delta.append((combo, r, corr))

# %%
results_delta_df = pd.DataFrame(
    results_delta,
    columns=["stations", "n_station", "correlation"]
)

results_delta_df = results_delta_df.sort_values(
    "correlation", ascending=False
)

results_delta_df.head(10)
# Out:
#                                    stations  n_station  correlation
# 2                                   (Ibun,)          1     0.306913
# 29  (Cikitu, Ibun, Kertasari, Paseh Cipaku)          4     0.277329
# 21                (Cikitu, Ibun, Kertasari)          3     0.268879
# 22             (Cikitu, Ibun, Paseh Cipaku)          3     0.267260
# 23        (Cikitu, Kertasari, Paseh Cipaku)          3     0.258749
# 9                            (Cikitu, Ibun)          2     0.255217
# 10                      (Cikitu, Kertasari)          2     0.249068
# 24          (Ibun, Kertasari, Paseh Cipaku)          3     0.246509
# 11                   (Cikitu, Paseh Cipaku)          2     0.246315
# 1                                 (Cikitu,)          1     0.241856

# %%
nan_df = pd.DataFrame({
    "NaN (%)": [
        ch_lagged[st].isna().mean() * 100
        for st in ch_lagged.columns
    ]
}, index=ch_lagged.columns)

nan_df
# Out:
#                 NaN (%)
# Cihawuk        0.516310
# Cikitu        30.194907
# Ibun          54.144309
# Kertasari      0.593756
# Paseh Cipaku   0.580849
